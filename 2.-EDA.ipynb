# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamonds = pd.read_csv('diamonds_clean.csv')
diamonds = diamonds.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53932.000000  53932.000000  53932.000000  53932.000000  53932.000000
# mean       0.797879     61.749336     57.457029   3932.136079      5.732007
# std        0.473986      1.432514      2.234064   3988.734835      1.119670
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.750000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z  clarity_corrected  color_corrected
# count  53932.000000  53932.000000       53932.000000     53932.000000
# mean       3.539798      3.539735           3.051101         3.405789
# std        0.692527      0.692051           1.647109         1.701165
# min        1.070000      1.070000           0.000000         0.000000
# 25%        2.910000      2.910000           2.000000         2.000000
# 50%        3.530000      3.530000           3.000000         3.000000
# 75%        4.040000      4.040000           4.000000         5.000000
# max       10.421888      8.060000           7.000000         6.000000

# %%
#LGTM

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#1/ The Carat / Clarity and table would affect the most bc the variability is higher

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here
color_price = diamonds.groupby('color').mean().sort_values('price', ascending=False)

# %%
color_price
# Out:
#           carat      depth      table        price         x         y  \
# color
# J      1.162137  61.887215  57.812393  5323.818020  6.519338  4.034477
# I      1.026927  61.846385  57.577278  5091.874954  6.222826  3.846369
# H      0.911627  61.836557  57.518176  4484.958805  5.984776  3.699147
# G      0.771088  61.757449  57.288060  3998.145173  5.678549  3.507966
# F      0.736509  61.694087  57.433148  3725.091938  5.616727  3.465938
# D      0.657715  61.698066  57.404355  3168.106436  5.417851  3.343320
# E      0.657867  61.662090  57.491201  3076.752475  5.411580  3.337767
#
#               z  clarity_corrected  color_corrected
# color
# J      4.033251           2.776353              0.0
# I      3.846369           2.964035              1.0
# H      3.699147           2.933871              2.0
# G      3.507966           3.463419              3.0
# F      3.465938           3.134605              4.0
# D      3.343320           2.691025              6.0
# E      3.337767           2.969889              5.0

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#Color J is the most expensive

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here
color_price['price'].plot()
# Out:
# <AxesSubplot:xlabel='color'>

# %%
diamonds.price.hist()
# Out:
# <AxesSubplot:>

# %%
#The worst the color is the more expensive it'll be...

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here
carat_price = diamonds.groupby('carat').mean().sort_values('price', ascending=False)

# %%
carat_price
# Out:
#            depth      table         price          x          y         z  \
# carat
# 3.51   62.500000  59.000000  18701.000000   9.660000   6.030000  6.030000
# 2.67   63.800000  58.000000  18686.000000   8.690000   5.540000  5.540000
# 4.50   65.800000  58.000000  18531.000000  10.230000   6.720000  6.720000
# 5.01   65.500000  59.000000  18018.000000  10.740000  10.421888  6.980000
# 2.57   61.066667  58.666667  17841.666667   8.860000   5.383333  5.383333
# ...          ...        ...           ...        ...        ...       ...
# 0.24   61.599213  57.488189    505.185039   3.990157   2.465591  2.465591
# 0.23   61.426621  58.034130    486.143345   3.946382   2.431468  2.431468
# 0.22   61.620000  60.400000    391.400000   3.898000   2.386000  2.386000
# 0.21   60.511111  58.444444    380.222222   3.874444   2.332222  2.332222
# 0.20   61.100000  59.333333    365.166667   3.786667   2.303333  2.303333
#
#        clarity_corrected  color_corrected
# carat
# 3.51            3.000000         0.000000
# 2.67            1.000000         4.000000
# 4.50            0.000000         0.000000
# 5.01            0.000000         0.000000
# 2.57            1.333333         3.666667
# ...                  ...              ...
# 0.24            4.972441         4.185039
# 0.23            4.901024         4.518771
# 0.22            2.600000         4.800000
# 0.21            2.666667         5.444444
# 0.20            2.833333         5.166667
#
# [273 rows x 8 columns]

# %%
#your comments

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#your code here
diamonds.carat.plot(kind='hist', bins= 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
table_price = diamonds.groupby('table').mean().sort_values('price', ascending=False)

# %%
table_price
# Out:
#           carat      depth         price         x         y         z  \
# table
# 95.0   2.010000  58.600000  13387.000000  8.320000  4.870000  4.870000
# 51.6   2.000000  61.000000  13203.000000  8.140000  4.970000  4.970000
# 50.0   1.510000  61.500000   8995.500000  7.380000  4.510000  4.510000
# 58.5   1.080000  61.940000   6499.700000  6.239000  3.884000  3.884000
# 69.0   1.170000  57.644444   6272.222222  6.797778  3.887778  3.887778
# ...         ...        ...           ...       ...       ...       ...
# 61.8   0.450000  60.100000   1262.000000  4.960000  2.990000  2.990000
# 53.1   0.396667  62.566667   1146.666667  4.676667  2.936667  2.936667
# 61.3   0.400000  62.000000    929.000000  4.690000  2.910000  2.910000
# 52.8   0.300000  62.350000    652.500000  4.285000  2.690000  2.690000
# 44.0   0.290000  62.800000    474.000000  4.200000  2.650000  2.650000
#
#        clarity_corrected  color_corrected
# table
# 95.0            2.000000         4.000000
# 51.6            4.000000         0.000000
# 50.0            2.000000         3.000000
# 58.5            2.800000         2.300000
# 69.0            2.666667         3.000000
# ...                  ...              ...
# 61.8            4.000000         4.000000
# 53.1            4.666667         2.333333
# 61.3            3.000000         4.000000
# 52.8            4.500000         2.500000
# 44.0            4.000000         5.000000
#
# [127 rows x 8 columns]

# %%
#th highest table is the most expensive but not direct link between table and price evolution

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here
clarity_price = diamonds.groupby('clarity').mean().sort_values('price', ascending=False)

# %%
clarity_price
# Out:
#             carat      depth      table        price         x         y  \
# clarity
# SI2      1.077602  61.771567  57.926823  5062.267356  6.404157  3.952642
# SI1      0.850482  61.853042  57.662541  3996.001148  5.888383  3.640636
# I1       1.283846  62.734278  58.303779  3924.168691  6.761093  4.229333
# VS2      0.763850  61.724249  57.418040  3924.166204  5.658633  3.492788
# VS1      0.727108  61.667968  57.313966  3839.144308  5.572860  3.437925
# VVS2     0.596202  61.663778  57.024990  3283.737071  5.218454  3.221465
# IF       0.505123  61.510615  56.507207  2864.839106  4.968402  3.061659
# VVS1     0.503131  61.624521  56.883881  2519.512315  4.961721  3.062132
#
#                 z  clarity_corrected  color_corrected
# clarity
# SI2      3.952642                1.0         3.469967
# SI1      3.640636                2.0         3.448450
# I1       4.224688                0.0         2.968961
# VS2      3.492788                3.0         3.494370
# VS1      3.437925                4.0         3.161812
# VVS2     3.221465                5.0         3.569483
# IF       3.061659                7.0         3.101676
# VVS1     3.062132                6.0         3.350848

# %%
#the clearer the diamond is the most expensive but not significant link between carat and price evolution

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
#The carat seems to be the most relevant feature
diamonds.corr()
# Out:
#                       carat     depth     table     price         x         y  \
# carat              1.000000  0.028221  0.181658  0.921610  0.977765  0.976405
# depth              0.028221  1.000000 -0.295700 -0.010670 -0.025097  0.096554
# table              0.181658 -0.295700  1.000000  0.127165  0.196130  0.155766
# price              0.921610 -0.010670  0.127165  1.000000  0.887227  0.881644
# x                  0.977765 -0.025097  0.196130  0.887227  1.000000  0.990558
# y                  0.976405  0.096554  0.155766  0.881644  0.990558  1.000000
# z                  0.976256  0.096379  0.155810  0.881924  0.990827  0.999771
# clarity_corrected -0.352877 -0.067286 -0.160401 -0.146886 -0.373009 -0.376409
# color_corrected   -0.291447 -0.047300 -0.026511 -0.172569 -0.270780 -0.274970
#
#                           z  clarity_corrected  color_corrected
# carat              0.976256          -0.352877        -0.291447
# depth              0.096379          -0.067286        -0.047300
# table              0.155810          -0.160401        -0.026511
# price              0.881924          -0.146886        -0.172569
# x                  0.990827          -0.373009        -0.270780
# y                  0.999771          -0.376409        -0.274970
# z                  1.000000          -0.376497        -0.274974
# clarity_corrected -0.376497           1.000000        -0.025678
# color_corrected   -0.274974          -0.025678         1.000000

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#Carat and X seems to have the most relevant distributions

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#carat = 0.92 correlation

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8493658995804616

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
